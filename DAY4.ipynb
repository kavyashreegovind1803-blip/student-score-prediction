# %%
import pandas as pd

# Create Student Dataset
data = {
    "Student": ["Asha", "Rahul", "Priya", "Ravi", "Sneha", "Kiran", "Anjali", "Vijay"],
    "Hours_Studied": [2, 5, 3, 8, 6, 7, 4, 9],
    "Attendance": [85, 90, 80, 95, 88, 92, 84, 98],
    "Previous_Marks": [60, 75, 55, 90, 78, 82, 68, 95],
    "Final_Score": [65, 80, 60, 94, 82, 88, 72, 97]
}

# Create DataFrame
df = pd.DataFrame(data)

print("Student Dataset")
print(df)

print("\nFirst Five Records")
print(df.head())

print("\nLast Five Records")
print(df.tail())

print("\nDataset Information")
print(df.info())

print("\nStatistical Summary")
print(df.describe())

print("\nStudent Names")
print(df["Student"])

print("\nHours Studied and Final Score")
print(df[["Hours_Studied", "Final_Score"]])

print("\nStudents who studied more than 5 hours")
print(df[df["Hours_Studied"] > 5])

print("\nAverage Final Score:", df["Final_Score"].mean())
print("Highest Final Score:", df["Final_Score"].max())
print("Lowest Final Score:", df["Final_Score"].min())

print("\nStudents sorted by Final Score")
print(df.sort_values(by="Final_Score", ascending=False))
# Out:
# Student Dataset
#   Student  Hours_Studied  Attendance  Previous_Marks  Final_Score
# 0    Asha              2          85              60           65
# 1   Rahul              5          90              75           80
# 2   Priya              3          80              55           60
# 3    Ravi              8          95              90           94
# 4   Sneha              6          88              78           82
# 5   Kiran              7          92              82           88
# 6  Anjali              4          84              68           72
# 7   Vijay              9          98              95           97
#
# First Five Records
#   Student  Hours_Studied  Attendance  Previous_Marks  Final_Score
# 0    Asha              2          85              60           65
# 1   Rahul              5          90              75           80
# 2   Priya              3          80              55           60
# 3    Ravi              8          95              90           94
# 4   Sneha              6          88              78           82
#
# Last Five Records
#   Student  Hours_Studied  Attendance  Previous_Marks  Final_Score
# 3    Ravi              8          95              90           94
# 4   Sneha              6          88              78           82
# 5   Kiran              7          92              82           88
# 6  Anjali              4          84              68           72
# 7   Vijay              9          98              95           97
#
# Dataset Information
# <class 'pandas.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Student         8 non-null      str
#  1   Hours_Studied   8 non-null      int64
#  2   Attendance      8 non-null      int64
#  3   Previous_Marks  8 non-null      int64
#  4   Final_Score     8 non-null      int64
# dtypes: int64(4), str(1)
# memory usage: 452.0 bytes
# None
#
# Statistical Summary
#        Hours_Studied  Attendance  Previous_Marks  Final_Score
# count        8.00000    8.000000        8.000000      8.00000
# mean         5.50000   89.000000       75.375000     79.75000
# std          2.44949    5.976143       13.917486     13.31755
# min          2.00000   80.000000       55.000000     60.00000
# 25%          3.75000   84.750000       66.000000     70.25000
# 50%          5.50000   89.000000       76.500000     81.00000
# 75%          7.25000   92.750000       84.000000     89.50000
# max          9.00000   98.000000       95.000000     97.00000
#
# Student Names
# 0      Asha
# 1     Rahul
# 2     Priya
# 3      Ravi
# 4     Sneha
# 5     Kiran
# 6    Anjali
# 7     Vijay
# Name: Student, dtype: str
#
# Hours Studied and Final Score
#    Hours_Studied  Final_Score
# 0              2           65
# 1              5           80
# 2              3           60
# 3              8           94
# 4              6           82
# 5              7           88
# 6              4           72
# 7              9           97
#
# Students who studied more than 5 hours
#   Student  Hours_Studied  Attendance  Previous_Marks  Final_Score
# 3    Ravi              8          95              90           94
# 4   Sneha              6          88              78           82
# 5   Kiran              7          92              82           88
# 7   Vijay              9          98              95           97
#
# Average Final Score: 79.75
# Highest Final Score: 97
# Lowest Final Score: 60
#
# Students sorted by Final Score
#   Student  Hours_Studied  Attendance  Previous_Marks  Final_Score
# 7   Vijay              9          98              95           97
# 3    Ravi              8          95              90           94
# 5   Kiran              7          92              82           88
# 4   Sneha              6          88              78           82
# 1   Rahul              5          90              75           80
# 6  Anjali              4          84              68           72
# 0    Asha              2          85              60           65
# 2   Priya              3          80              55           60
