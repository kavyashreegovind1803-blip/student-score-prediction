# %% [markdown]
# #DAY 2 - PYTHON VARIABLES AND DATA TYPES

# %%
name = "Kavyashree"
age = 21

print("Name:", name)
print("Age:", age)
# Out:
# Name: Kavyashree
# Age: 21

# %%
a = 10
b = 10.5
c = "Python"
d = True

print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
x = 20
y = 5

print("Addition:", x + y)
print("Subtraction:", x - y)
print("Multiplication:", x * y)
print("Division:", x / y)
# Out:
# Addition: 25
# Subtraction: 15
# Multiplication: 100
# Division: 4.0

# %%
marks = 85

if marks >= 35:
    print("Pass")
else:
    print("Fail")
# Out:
# Pass

# %%
for i in range(1, 6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i = 1
while i <= 5:
    print(i)
    i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
def square(n):
    return n * n

print(square(6))
# Out:
# 36

# %%
num = 10

if num % 2 == 0:
    print("Even Number")
else:
    print("Odd Number")
# Out:
# Even Number
